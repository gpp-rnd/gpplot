# %% [markdown]
# This notebook demonstrates how to make a point density plot using gpplot.

# %%
# for development 
from gpplot_dev import add_gpplot_path
add_gpplot_path()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gpplot import point_density_plot

# %%
nsamps = 20000
data = pd.DataFrame({'x': np.random.normal(size = nsamps)}, index = range(nsamps))
data['y'] = 2*data['x'] + np.random.normal(size = nsamps)
ax = point_density_plot(data, 'x', 'y')
# Out:
# /Users/pdeweird/anaconda3/envs/gpplot/lib/python3.6/site-packages/seaborn/relational.py:913: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   scout = ax.scatter([], [], **kws)
# /Users/pdeweird/anaconda3/envs/gpplot/lib/python3.6/site-packages/seaborn/relational.py:950: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   points = ax.scatter(*args, **kws)

# %% [markdown]
# We can change the colormap of the plot

# %%
ax = point_density_plot(data, 'x', 'y', palette='plasma')

# %% [markdown]
# We can add a legend for the color mapping

# %%
point_density_plot(data, 'x', 'y', legend = 'brief')

# %% [markdown]
# We can change the resolution for estimating the point density

# %%
point_density_plot(data, 'x', 'y', bins = [5,5])

# %%
point_density_plot(data, 'x', 'y', bins = [50,50])

# %% [markdown]
# We can make the plot square by using the "ax" argument

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax = point_density_plot(data, 'x', 'y', ax = ax)
