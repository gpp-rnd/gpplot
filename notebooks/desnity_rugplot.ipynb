# %% [markdown]
# Here we demonstrate creating a plot where the first subplot is a distribution of values and the subsequent subplots are rugplots of values for some discrete number of variables

# %%
# for development 
from gpplot_dev import add_gpplot_path
add_gpplot_path()

# %%
import seaborn as sns
from gpplot import density_rugplot

# %%
data = sns.load_dataset('iris')
fig, ax = density_rugplot(data, 'petal_length', 'species', ['setosa', 'virginica'])

# %% [markdown]
# We can add a reference line across all plots

# %%
fig, ax = density_rugplot(data, 'petal_length', 'species', ['setosa', 'virginica'], ref_line=5)

# %% [markdown]
# We can change the color and opacity of the rugplot lines

# %%
fig, ax = density_rugplot(data, 'petal_length', 'species', ['setosa', 'virginica'], 
                          density_color='navy', rug_color='skyblue', rug_alpha=1)

# %% [markdown]
# We can pass key word arguments to adjust the line style

# %%
fig, ax = density_rugplot(data, 'petal_length', 'species', ['setosa', 'virginica'], linestyle='dashed', linewidth=2)

# %%
ax
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1020b1048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1020d3240>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10204a198>],
#       dtype=object)
